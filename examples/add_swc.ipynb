# %%
# %gui qt5
# Note that this Magics command needs to be run in a cell
# before any of the Napari objects are instantiated to
# ensure it has time to finish executing before they are
# called

import napari
import numpy as np

# %%
## show conensus neuron G-002
# parameters
consen_neuron_path = '2018-08-01_G-002_consensus.swc'
spacing = np.array([0.29875923,0.3044159,0.98840415])
origin = np.array([70093.276,15071.596,29306.737])

# %%
viewer = napari.Viewer(ndisplay=3)
viewer.add_swc(swc_path=consen_neuron_path, spacing=spacing, origin=origin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/github/napari/napari/_qt/qt_dims_slider.py in <lambda>(value)
#     131         # Listener to be used for sending events back to model:
#     132         slider.valueChanged.connect(
# --> 133             lambda value: self.dims.set_point(self.axis, value)
#     134         )
#     135
#
# ~/github/napari/napari/components/dims.py in set_point(self, axis, value)
#     357         if self.point[axis] != value:
#     358             self._point[axis] = value
# --> 359             self.events.axis(axis=axis, value=value)
#     360
#     361     def set_interval(self, axis: int, interval: Sequence[Union[int, float]]):
#
# ~/github/napari/napari/util/event.py in __call__(self, *args, **kwargs)
#     506                     continue
#     507
# --> 508                 self._invoke_callback(cb, event)
#     509                 if event.blocked:
#     510                     break
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     527                 self.print_callback_errors,
#     528                 self,
# --> 529                 cb_event=(cb, event),
#     530             )
#     531
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     521     def _invoke_callback(self, cb, event):
#     522         try:
# --> 523             cb(event)
#     524         except Exception:
#     525             _handle_exception(
#
# ~/github/napari/napari/components/viewer_model.py in <lambda>(e)
#      88         self.dims.events.ndisplay.connect(lambda e: self._update_layers())
#      89         self.dims.events.order.connect(lambda e: self._update_layers())
# ---> 90         self.dims.events.axis.connect(lambda e: self._update_layers())
#      91         self.layers.events.added.connect(self._on_layers_change)
#      92         self.layers.events.removed.connect(self._on_layers_change)
#
# ~/github/napari/napari/components/viewer_model.py in _update_layers(self, layers)
#    1109             for axis in range(layer.dims.ndim):
#    1110                 point = self.dims.point[axis + offset]
# -> 1111                 layer.dims.set_point(axis, point)
#    1112
#    1113     def _update_active_layer(self, event):
#
# ~/github/napari/napari/components/dims.py in set_point(self, axis, value)
#     357         if self.point[axis] != value:
#     358             self._point[axis] = value
# --> 359             self.events.axis(axis=axis, value=value)
#     360
#     361     def set_interval(self, axis: int, interval: Sequence[Union[int, float]]):
#
# ~/github/napari/napari/util/event.py in __call__(self, *args, **kwargs)
#     506                     continue
#     507
# --> 508                 self._invoke_callback(cb, event)
#     509                 if event.blocked:
#     510                     break
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     527                 self.print_callback_errors,
#     528                 self,
# --> 529                 cb_event=(cb, event),
#     530             )
#     531
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     521     def _invoke_callback(self, cb, event):
#     522         try:
# --> 523             cb(event)
#     524         except Exception:
#     525             _handle_exception(
#
# ~/github/napari/napari/layers/base/base.py in <lambda>(e)
#     174         self.dims.events.ndisplay.connect(lambda e: self._update_dims())
#     175         self.dims.events.order.connect(lambda e: self._update_dims())
# --> 176         self.dims.events.axis.connect(lambda e: self._set_view_slice())
#     177
#     178         self.mouse_move_callbacks = []
#
# ~/github/napari/napari/layers/shapes/shapes.py in _set_view_slice(self)
#     706         self._set_highlight(force=True)
#     707         self._update_thumbnail()
# --> 708         self._update_coordinates()
#     709         self.events.set_data()
#     710
#
# ~/github/napari/napari/layers/base/base.py in _update_coordinates(self)
#     546         self.coordinates = tuple(coords)
#     547         self._value = self.get_value()
# --> 548         self.status = self.get_message()
#     549
#     550     def get_message(self):
#
# ~/github/napari/napari/layers/base/base.py in get_message(self)
#     560
#     561         full_coord = np.round(
# --> 562             np.multiply(self.coordinates, full_scale) + full_translate
#     563         ).astype(int)
#     564
#
# TypeError: unsupported operand type(s) for *: 'slice' and 'float'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/github/napari/napari/_qt/qt_dims_slider.py in <lambda>(value)
#     131         # Listener to be used for sending events back to model:
#     132         slider.valueChanged.connect(
# --> 133             lambda value: self.dims.set_point(self.axis, value)
#     134         )
#     135
#
# ~/github/napari/napari/components/dims.py in set_point(self, axis, value)
#     357         if self.point[axis] != value:
#     358             self._point[axis] = value
# --> 359             self.events.axis(axis=axis, value=value)
#     360
#     361     def set_interval(self, axis: int, interval: Sequence[Union[int, float]]):
#
# ~/github/napari/napari/util/event.py in __call__(self, *args, **kwargs)
#     506                     continue
#     507
# --> 508                 self._invoke_callback(cb, event)
#     509                 if event.blocked:
#     510                     break
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     527                 self.print_callback_errors,
#     528                 self,
# --> 529                 cb_event=(cb, event),
#     530             )
#     531
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     521     def _invoke_callback(self, cb, event):
#     522         try:
# --> 523             cb(event)
#     524         except Exception:
#     525             _handle_exception(
#
# ~/github/napari/napari/components/viewer_model.py in <lambda>(e)
#      88         self.dims.events.ndisplay.connect(lambda e: self._update_layers())
#      89         self.dims.events.order.connect(lambda e: self._update_layers())
# ---> 90         self.dims.events.axis.connect(lambda e: self._update_layers())
#      91         self.layers.events.added.connect(self._on_layers_change)
#      92         self.layers.events.removed.connect(self._on_layers_change)
#
# ~/github/napari/napari/components/viewer_model.py in _update_layers(self, layers)
#    1109             for axis in range(layer.dims.ndim):
#    1110                 point = self.dims.point[axis + offset]
# -> 1111                 layer.dims.set_point(axis, point)
#    1112
#    1113     def _update_active_layer(self, event):
#
# ~/github/napari/napari/components/dims.py in set_point(self, axis, value)
#     357         if self.point[axis] != value:
#     358             self._point[axis] = value
# --> 359             self.events.axis(axis=axis, value=value)
#     360
#     361     def set_interval(self, axis: int, interval: Sequence[Union[int, float]]):
#
# ~/github/napari/napari/util/event.py in __call__(self, *args, **kwargs)
#     506                     continue
#     507
# --> 508                 self._invoke_callback(cb, event)
#     509                 if event.blocked:
#     510                     break
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     527                 self.print_callback_errors,
#     528                 self,
# --> 529                 cb_event=(cb, event),
#     530             )
#     531
#
# ~/github/napari/napari/util/event.py in _invoke_callback(self, cb, event)
#     521     def _invoke_callback(self, cb, event):
#     522         try:
# --> 523             cb(event)
#     524         except Exception:
#     525             _handle_exception(
#
# ~/github/napari/napari/layers/base/base.py in <lambda>(e)
#     174         self.dims.events.ndisplay.connect(lambda e: self._update_dims())
#     175         self.dims.events.order.connect(lambda e: self._update_dims())
# --> 176         self.dims.events.axis.connect(lambda e: self._set_view_slice())
#     177
#     178         self.mouse_move_callbacks = []
#
# ~/github/napari/napari/layers/shapes/shapes.py in _set_view_slice(self)
#     706         self._set_highlight(force=True)
#     707         self._update_thumbnail()
# --> 708         self._update_coordinates()
#     709         self.events.set_data()
#     710
#
# ~/github/napari/napari/layers/base/base.py in _update_coordinates(self)
#     546         self.coordinates = tuple(coords)
#     547         self._value = self.get_value()
# --> 548         self.status = self.get_message()
#     549
#     550     def get_message(self):
#
# ~/github/napari/napari/layers/base/base.py in get_message(self)
#     560
#     561         full_coord = np.round(
# --> 562             np.multiply(self.coordinates, full_scale) + full_translate
#     563         ).astype(int)
#     564
#
# TypeError: unsupported operand type(s) for *: 'slice' and 'float'
# <Shapes layer 'Shapes' at 0x13174d240>
